# %%
import spacy
import os
import pandas as pd
import geopy 
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup #Parses HTML content
from collections import Counter #Counts item frequencies in a list
from geopy.extra.rate_limiter import RateLimiter
from spacy import displacy

# %% [markdown]
# ### Get URL Text

# %%
url = "https://www.cnn.com/travel/article/experts-guide-to-great-american-road-trips/index.html"
data = requests.get(url)

# %%
#Parse out HTML tags and clean up newlines
soup = BeautifulSoup(data.content, 'html.parser')
text = soup.get_text()
text = text.strip().replace("\n", " ").replace("\r", " ")

# %% [markdown]
# ### Load the spacy model
#
# In addition to installing spacy, need to install the model with:
#
# requires conda install -c conda-forge spacy-model-en_core_web_lg

# %%
nlp = spacy.load("en_core_web_lg")

# %%
text = "Time!In 2013, a bespectacled Sunday school teacher from Atlanta, Georgia, drove from New York to Redondo Beach, California in a world record-setting 28 hours and 50 minutes.We can\'t recommend this -- Ed Bolian and his co-driver averaged 98 miles per hour during the journey, and could easily have gone to jail in any number of states.It\'s also a loss from a travel perspective. Any itinerary should leave room to sample America\'s rich and nutty menu of roadside attractions. We\'ve broken them down into a few helpful categories."

# %% [markdown]
# ## Natural Language Processing to tokenize and label text

# %%
text
# Out:
# 'Great  American road trip guide | CNN TravelDestinationsFood & DrinkNewsStayVideoSearchMenuBusiness TravellerEndless highway: How to drive the ultimate American road tripCorinne Purtill, for CNN • Updated 12th August 2016FacebookTwitterEmailUp nextQantas goes back to basics08:09The ancient city that\'s back on the bucket list08:28Revisiting Rome, 1947 style07:21The Evolution of the Kangaroo Route07:26The Ultra Long Haul, Reimagined 08:33Step back in time on the Kangaroo Route08:10The Chinese travel revolution08:39Putting China\'s airlines to the test06:13Chinese travel boom: The game-changers 07:43Thailand\'s tourism boom 09:02(CNN) — Ah, the great American road trip. It\'s a rite of passage, a combination of nostalgia, discovery and misadventure ideally set against a sweeping landscape and killer tunes.The beauty of the road trip lies in its democratic simplicity: little more is needed beyond a map and a functioning vehicle for a Kerouac-worthy journey. We\'ve boiled the planning down to the following essential considerations:Route!How much time? Desert or forest? Big cities, country routes or a bit of both?Guides abound for trips along the classic U.S. routes -- California\'s Highway, the old Route 66, the New England fall foliage tour. If you want a unique itinerary, there are plenty of resources to help design a journey that leaves room for unexpected adventure while taking in sights you know you don\'t want to miss.That\'s what Barbara McKirdy discovered in 2014 when she and husband Gregg drove from Connecticut to Florida in a borrowed RV. With no fixed schedule, the pair found themselves drawn to the coast in the evenings, where they\'d pull into a beach parking lot and watch the sunset together."It was wonderful," McKirdy says. "We had no itinerary starting out, we had only two spots planned. We were kind of winging it."If you prefer a data-driven decision, genius Randy Olson -- the guy who mastered the art of searching for Waldo -- has planned the ideal U.S. road trip. His 13,699-mile route is the shortest way to take in a national park, monument, historic site or natural landmark in each of the lower 48 states.READ: 10 dream trips every traveler should experienceThe Grand Canyon is a regular road trip destination. No "Thelma and Louise" moments please.MLADEN ANTONOV/AFP/Getty ImagesTime!In 2013, a bespectacled Sunday school teacher from Atlanta, Georgia, drove from New York to Redondo Beach, California in a world record-setting 28 hours and 50 minutes.We can\'t recommend this -- Ed Bolian and his co-driver averaged 98 miles per hour during the journey, and could easily have gone to jail in any number of states.It\'s also a loss from a travel perspective. Any itinerary should leave room to sample America\'s rich and nutty menu of roadside attractions. We\'ve broken them down into a few helpful categories.ClassicsSome of the U.S.\'s most iconic sights are road trip staples. Mount Rushmore. The Grand Canyon. Sequoia National Park.And if they\'re not classics yet, they should be. The town of Winslow, Arizona has actually parked a flatbed Ford on a corner of the old U.S. Route 66, in homage to the Eagles song. Could you honestly be within 50 miles of that and not go take a picture? How could you live with yourself?SuperlativesAmerica\'s position as a world leader has taken a battering in recent years. China\'s economy is creeping up on the United States as the world\'s largest. The US doesn\'t even have the planet\'s highest obesity rate anymore.Yet the highways are lined with examples of uncontested American dominance. The world\'s tallest thermometer (Baker, California), world\'s largest ball of twine (subject of intense rivalry between Cawker City, Kansas and Darwin, Minnesota, and world\'s largest bottle of ketchup (Collinsville, Illinois) all prove that where it counts, America remains number one. MORE: 8 roadside curiosities worth the stoplevartInexplicably oversized animalsYou need to stretch your legs and use the  ...

# %%
doc = nlp(text)
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Great
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  road trip guide |
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  TravelDestinationsFood &amp; DrinkNewsStayVideoSearchMenuBusiness TravellerEndless highway: How to drive the ultimate
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  road tripCorinne
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Purtill
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  • Updated
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12th August
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  2016FacebookTwitterEmailUp nextQantas goes back to basics08:09The ancient city that's back on the bucket list08:28Revisiting
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rome
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1947
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     style07:21The Evolution of the Kangaroo Route07:26The Ultra Long Haul
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# , Reimagined
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     08:33Step
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  back in time on the Kangaroo Route08:10The
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  travel revolution08:39Putting
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's airlines to the test06:13Chinese travel boom: The game-changers
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     07:43Thailand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's tourism boom 09:02(CNN) — Ah, the great
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  road trip. It's a rite of passage, a combination of nostalgia, discovery and misadventure ideally set against a sweeping landscape and killer tunes.The beauty of the road trip lies in its democratic simplicity: little more is needed beyond a map and a functioning vehicle for a
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kerouac
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# -worthy journey. We've boiled the planning down to the following essential considerations:Route!How much time? Desert or forest? Big cities, country routes or a bit of both?Guides abound for trips along the classic
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  routes --
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     California
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's Highway, the old
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Route 66
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# , the
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New England
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  fall foliage tour. If you want a unique itinerary, there are plenty of resources to help design a journey that leaves room for unexpected adventure while taking in sights you know you don't want to miss.That's what
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barbara McKirdy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  discovered in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2014
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  when she and husband
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gregg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1;

# %% [markdown]
# ### Detected places to dataframe

# %%
locations = []

locations.extend([[ent.text, ent.start, ent.end, ent.label_, spacy.explain(ent.label_)] for ent in doc.ents ])
df_all = pd.DataFrame(locations, columns=['Location', 'start','end', 'label', 'meaning'])
df_all
# Out:
#                                               Location  start   end   label  \
# 0                                             American      2     3    NORP
# 1                                                  CNN      7     8     ORG
# 2                                             American     19    20    NORP
# 3                                              Purtill     22    23     ORG
# 4                                                  CNN     25    26     ORG
# ..                                                 ...    ...   ...     ...
# 142                                    NewslettersWork   1762  1763  PERSON
# 143                   UsePrivacy PolicyAccessibility &   1768  1771     ORG
# 144  FootageCNN NewsourceSitemap© 2022 Cable News N...   1781  1788     ORG
# 145                               Warner Media Company   1790  1793     ORG
# 146                                                CNN   1798  1799     ORG
#
#                                             meaning
# 0    Nationalities or religious or political groups
# 1           Companies, agencies, institutions, etc.
# 2    Nationalities or religious or political groups
# 3           Companies, agencies, institutions, etc.
# 4           Companies, agencies, institutions, etc.
# ..                                              ...
# 142                     People, including fictional
# 143         Companies, agencies, institutions, etc.
# 144         Companies, agencies, institutions, etc.
# 145         Companies, agencies, institutions, etc.
# 146         Companies, agencies, institutions, etc.
#
# [147 rows x 5 columns]

# %%
label_unique = list(df_all['label'].unique())

for l in label_unique:
    print(l)
    print(spacy.explain(l))
# Out:
# NORP
# Nationalities or religious or political groups
# ORG
# Companies, agencies, institutions, etc.
# DATE
# Absolute or relative dates or periods
# GPE
# Countries, cities, states
# EVENT
# Named hurricanes, battles, wars, sports events, etc.
# PERSON
# People, including fictional
# FAC
# Buildings, airports, highways, bridges, etc.
# LOC
# Non-GPE locations, mountain ranges, bodies of water
# CARDINAL
# Numerals that do not fall under another type
# QUANTITY
# Measurements, as of weight or distance
# TIME
# Times smaller than a day
# WORK_OF_ART
# Titles of books, songs, etc.
# ORDINAL
# "first", "second", etc.

# %%
# Just the locations

loc_codes = ['GPE', 'LOC']

df_places = df_all.loc[df_all['label'].isin(loc_codes)]

df_places
# Out:
#                        Location  start   end label  \
# 6                          Rome     45    46   GPE
# 11                        China     70    71   GPE
# 15                         U.S.    189   190   GPE
# 16                   California    192   193   GPE
# 18                  New England    202   204   LOC
# 22                  Connecticut    259   260   GPE
# 23                      Florida    261   262   GPE
# 28                          "If    329   330   GPE
# 31                         U.S.    357   358   GPE
# 35   experienceThe Grand Canyon    400   403   LOC
# 42                      Atlanta    434   435   GPE
# 43                      Georgia    436   437   GPE
# 44                     New York    440   442   GPE
# 45                Redondo Beach    443   445   GPE
# 46                   California    446   447   GPE
# 50                      America    511   512   GPE
# 51                         U.S.    535   536   GPE
# 53             The Grand Canyon    548   551   LOC
# 55                      Winslow    571   572   GPE
# 56                      Arizona    573   574   GPE
# 58                         U.S.    586   587   GPE
# 63                        China    633   634   GPE
# 64            the United States    640   643   GPE
# 65                           US    650   651   GPE
# 68                   California    683   684   GPE
# 69                  Cawker City    698   700   GPE
# 70                       Kansas    701   702   GPE
# 72                    Minnesota    705   706   GPE
# 73                 Collinsville    715   716   GPE
# 74                     Illinois    717   718   GPE
# 75                      America    726   727   GPE
# 78                      Cabazon    771   772   GPE
# 79                   California    773   774   GPE
# 80                      Katoosa    778   779   GPE
# 81                     Oklahoma    780   781   GPE
# 82                    Leicester    785   786   GPE
# 83                      Vermont    787   788   GPE
# 85                West Virginia    794   796   GPE
# 86                      Margate    800   801   GPE
# 87                   New Jersey    802   804   GPE
# 88                      buffalo    806   807   GPE
# 89                    Jamestown    808   809   GPE
# 90                 North Dakota    810   812   GPE
# 91                   Rapid City    817   819   GPE
# 92                      America    826   827   GPE
# 94                      Arizona    874   875   GPE
# 97                   California    888   889   GPE
# 99                     Amarillo    893   894   GPE
# 100                       Texas    895   896   GPE
# 102                    Nebraska    901   902   GPE
# 106                          US   1014  1015   GPE
# 111                          US   1156  1157   GPE
# 112                          US   1196  1197   GPE
# 128                  California   1651  1652   GPE
# 129                  Washington   1653  1654   GPE
# 130                        D.C.   1655  1656   GPE
#
#                                                meaning
# 6                            Countries, cities, states
# 11                           Countries, cities, states
# 15                           Countries, cities, states
# 16                           Countries, cities, states
# 18   Non-GPE locations, mountain ranges, bodies of ...
# 22                           Countries, cities, states
# 23                           Countries, cities, states
# 28                           Countries, cities, states
# 31                           Countries, cities, states
# 35   Non-GPE locations, mountain ranges, bodies of ...
# 42                           Countries, cities, states
# 43                           Countries, cities, states
# 44                           Countries, cities, states
# 45                           Countries, cities, states
# 46                           Countries, cities, states
# 50                           Countries, cities, states
# 51                           Countries, cities, states
# 53   Non-GPE locations, mountain ranges, bodies of ...
# 55                           Countries, cities, states
# 56                           Countries, cities, states
# 58                           Countries, cities, states
# 63                           Countries, cities, states
# 64                           Countries, cities, states
# 65                           Countries, cities, states
# 68                           Countries, cities, states
# 69                           Countries, cities, states
# 70                           Countries, cities, states
# 72                           Countries, cities, states
# 73                           Countries, cities, states
# 74                           Countries, cities, states
# 75                           Countries, cities, states
# 78                           Countries, cities, states
# 79                           Countries, cities, states
# 80                           Countries, cities, states
# 81                           Countries, cities, states
# 82                           Countries, cities, states
# 83                           Countries, cities, states
# 85                           Countries, cities, states
# 86                           Countries, cities, states
# 87                           Countries, cities, states
# 88                           Countries, cities, states
# 89                           Countries, cities, states
# 90                           Countries, cities, states
# 91                           Countries, cities, states
# 92                           Countries, cities, states
# 94                           Countries, cities, states
# 97                           Countries, cities, states
# 99                           Countries, cities, states
# 100                          Countries, cities, states
# 102                          Countries, cities, states
# 106                          Countries, cities, states
# 111                          Countries, cities, states
# 112                          Countries, cities, states
# 128                          Countries, cities, states
# 129                          Countries, cities, states
# 130                          Countries, cities, states

# %% [markdown]
# ### Geocode locations with geopy

# %%
locator = geopy.geocoders.Nominatim(user_agent='mygeocoder')
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)
# geocode = RateLimiter(locator.geocode('Atlanta', addressdetails=True), min_delay_seconds=1)

# %%
locations = [ locator.geocode(loc, addressdetails=True) for loc in list(df_places['Location'])]

# %%
locations_raw = []
city = []
state = []
country = []

for loc in locations:
    if loc is not None:
        add = loc.raw['address']
        locations_raw.append(add)
        add_parts = list(add.keys())
        
        if 'city' in add_parts:
            city.append(add['city'])
        else:
            city.append('')

        if 'state' in add_parts:
            state.append(add['state'])
        else:
            state.append('')

        if 'county' in add_parts:
            country.append(add['country'])
        else:
            country.append('')

    else:
        locations_raw.append('')
        city.append('')
        state.append('')
        country.append('')

# %%
df_places['add_raw'] = locations_raw
df_places['city'] = city
df_places['state'] = state
df_places['country'] = country
df_places.tail()
# Out:
# <ipython-input-33-7de38e86715d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_places['add_raw'] = locations_raw
# <ipython-input-33-7de38e86715d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_places['city'] = city
# <ipython-input-33-7de38e86715d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_places['state'] = state
# <ipython-input-33-7de38e86715d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_places['country'] = country
#        Location  start   end label                    meaning  \
# 111          US   1156  1157   GPE  Countries, cities, states
# 112          US   1196  1197   GPE  Countries, cities, states
# 128  California   1651  1652   GPE  Countries, cities, states
# 129  Washington   1653  1654   GPE  Countries, cities, states
# 130        D.C.   1655  1656   GPE  Countries, cities, states
#
#                                                add_raw        city  \
# 111  {'country': 'United States', 'country_code': '...
# 112  {'country': 'United States', 'country_code': '...
# 128  {'state': 'California', 'country': 'United Sta...
# 129  {'city': 'Washington', 'state': 'District of C...  Washington
# 130  {'city': 'Washington', 'state': 'District of C...  Washington
#
#                     state country
# 111
# 112
# 128            California
# 129  District of Columbia
# 130  District of Columbia

# %% [markdown]
# ### Dataframe to input JSON for geonenrichment

# %%
locations_raw = []
cities = []
states = []
countries = []

for loc in locations:
    if loc is not None:
        add = loc.raw['address']
        locations_raw.append(add)
        add_parts = list(add.keys())
        
        if 'city' in add_parts:
            cities.append(add['city'])
        else:
            cities.append('')

        if 'state' in add_parts:
            states.append(add['state'])
        else:
            states.append('')

        if 'county' in add_parts:
            countries.append(add['country'])
        else:
            countries.append('')

    else:
        locations_raw.append('')
        cities.append('')
        states.append('')
        countries.append('')

# %%
import json

df_places['add_raw'] = locations_raw
df_places['city'] = cities
df_places['state'] = states
df_places['country'] = countries

# write the us cities to json file

df_export = df_places.loc[(df_places['country'] == 'United States') & (df_places['state'] != '') & (df_places['city'] != '')]

out_dict = []

for idx, row in df_export.iterrows():
    out_dict.append(
        {'city': row['city'],
        'state': row['state']}
    )

out_json = r"C:\Projects\HTM_2022\locately\locations.json"

f = open(out_json, "w")
json.dump(out_dict, f)
f.close()
# Out:
# <ipython-input-35-2db60c0c58ed>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_places['add_raw'] = locations_raw
# <ipython-input-35-2db60c0c58ed>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_places['city'] = cities
# <ipython-input-35-2db60c0c58ed>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_places['state'] = states
# <ipython-input-35-2db60c0c58ed>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_places['country'] = countries

# %%
out_dict
# Out:
# [{'city': 'Collinsville', 'state': 'Illinois'},
#  {'city': 'Buffalo', 'state': 'New York'},
#  {'city': 'Rapid City', 'state': 'South Dakota'},
#  {'city': 'Amarillo', 'state': 'Texas'}]
